# %% [markdown]
# # File management
# This notebook let's you:
# - Make filenames uniform
# - select and move files by asset or date

# %%
# Import
from pathlib import Path
from data_manager.image_data_manager import parse_root,organize, write_data_files_to_csv, filter_by, move_organized,copy_organized

# %%
parsed = parse_root(Path(r"C:\Falcker\cloud\falcker\AI\OlieDetectie\Willem_set\test"))

# %%
write_data_files_to_csv(parsed)

# %%
filtered= filter_by(parsed, assets=["F51"], mode="include")

# %%
move_organized(organize(filtered))
