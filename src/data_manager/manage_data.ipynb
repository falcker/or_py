# %% [markdown]
# # File management
# This notebook let's you:
# - Make filenames uniform
# - select and move files by asset or date

# %%
# Import
from pathlib import Path
from data_manager.image_data_manager import parse_root,organize, write_data_files_to_csv, filter_by, move_organized,copy_organized,default_rename_files

# %%
parsed = parse_root(Path(r"C:\Falcker\cloud\falcker\AI\OlieDetectie\Willem_set\Alles"))

# %%
write_data_files_to_csv(parsed)

# %%
filtered= filter_by(parsed, assets=["F53"], mode="include")

# %%
filtered

# %%
parsed = default_rename_files(parsed)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 parsed = default_rename_files(parsed)
#
# File ~\Documents\GitHub\or_py\src\data_manager\image_data_manager.py:160, in default_rename_files(data_files)
#     159 def default_rename_files(data_files: list[DataFile]) -> list[DataFile]:
# --> 160     return rename_files(data_files, rename_default)
#
# File ~\Documents\GitHub\or_py\src\data_manager\image_data_manager.py:156, in rename_files(data_files, new_name_func)
#     154 renamed_files = []
#     155 for data_file in data_files:
# --> 156     renamed_files.append(rename_file(data_file, new_name_func))
#     157 return renamed_files
#
# File ~\Documents\GitHub\or_py\src\data_manager\image_data_manager.py:150, in rename_file(data_file, new_name_func, auto_increment)
#     148             new_path = data_file.path.parent / f"{base_name}_{i}{suffix}"
#     149             i += 1
# --> 150 data_file.path.rename(new_path)
#     151 return DataFile(new_path, data_file.filename)
#
# File ~\AppData\Roaming\uv\python\cpython-3.11.13-windows-x86_64-none\Lib\pathlib.py:1175, in Path.rename(self, target)
#    1165 def rename(self, target):
#    1166     """
#    1167     Rename this path to the target path.
#    1168
#    (...)
#    1173     Returns the new Path instance pointing to the target path.
#    1174     """
# -> 1175     os.rename(self, target)
#    1176     return self.__class__(target)
#
# FileExistsError: [WinError 183] Kan geen bestand maken dat al bestaat: 'C:\\Falcker\\cloud\\falcker\\AI\\OlieDetectie\\Willem_set\\Alles\\202507014-F02.jpeg' -> 'C:\\Falcker\\cloud\\falcker\\AI\\OlieDetectie\\Willem_set\\Alles\\F02_20250701.jpeg'

# %%
move_organized(organize(parsed))
